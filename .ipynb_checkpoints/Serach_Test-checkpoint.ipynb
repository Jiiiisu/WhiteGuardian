# %%
import os
import winreg
import win32com.client
import pandas as pd
from datetime import date, datetime, timedelta

# 바로가기 파일경로를 사용하여 대상 파일의 실제 경로 찾아 반환하는 함수
def get_target_path(lnk_path):
    shell = win32com.client.Dispatch("WScript.Shell")
    shortcut = shell.CreateShortCut(lnk_path)
    target_path = shortcut.Targetpath
    return target_path

# 해당 파일 타입에 대한 기본 프로그램 찾는 함수
def get_associated_program(ext):
    prog_id = ''
    try:
        with winreg.OpenKey(winreg.HKEY_CLASSES_ROOT, ext, 0, winreg.KEY_READ) as key:
            prog_id = winreg.QueryValueEx(key, None)[0]
        with winreg.OpenKey(winreg.HKEY_CLASSES_ROOT, f'{prog_id}\\shell\\open\\command', 0, winreg.KEY_READ) as key:
            command = winreg.QueryValueEx(key, None)[0]
        return command
    except FileNotFoundError:
        return f'{ext} 파일에 대한 기본 프로그램을 찾을 수 없습니다.'

# 2주내로 사용한 파일의 정보 정렬, 출력, 저장 함수
def SortTwoWeeks():
    folder_path = os.path.join(os.getenv('APPDATA'), 'Microsoft', 'Windows', 'Recent')
    file_list = os.listdir(folder_path)
    today = date.today()
    two_weeks_ago = today - timedelta(days=14)
    data =[]
    
    #파일 목록을 수정 시간 기준으로 정렬 (내림차순)
    sorted_files =  sorted(file_list, key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)
    
    #2주간 사용한 파일 목록 딕셔너리 형태로 저장.
    recent_files = {}
    for f_name in sorted_files:
        file_path = os.path.join(folder_path,f_name)
        time=os.path.getmtime(file_path)
        file_date=datetime.fromtimestamp(time).date()
        if two_weeks_ago <= file_date <= today:
            recent_files[f_name] = {'file_date': file_date, 'program': ''}
            
    # 어떤 프로그램으로 열렸는지 확인
    for f_name, file_info in recent_files.items():
        file_ext = os.path.splitext(f_name)[1]
        if file_ext == '.lnk':  # 바로가기 파일인 경우 처리
            file_path = os.path.join(folder_path, f_name)
            target_path = get_target_path(file_path)
            if target_path:
                file_ext = os.path.splitext(target_path)[1]  # 대상 파일의 확장자로 변경
                file_info['program'] = get_associated_program(file_ext)
            else:
                file_info['program'] = '바로가기 대상 파일을 찾을 수 없습니다.'
        else:
            file_info['program'] = get_associated_program(file_ext)

    # 딕셔너리 형태로 저장된 최근 2주간 사용한 파일 목록을 출력. 데이터셋 저장
    for f_name, file_info in recent_files.items():
        skip_file = False  # 파일을 건너뛸지 결정하는 변수

        base_name, ext = os.path.splitext(f_name)
        if ext == ".lnk":
            base_name, ext = os.path.splitext(
                os.path.basename(get_target_path(os.path.join(folder_path, f_name)))
            )

        program = os.path.basename(file_info["program"])

        # 기본 프로그램을 찾을 수 없거나 바로가기 대상 파일을 찾을 수 없는 경우 체크 후 출력하지 않음
        if "기본 프로그램을 찾을 수 없습니다" in program or "바로가기 대상 파일을 찾을 수 없습니다" in program:
            skip_file = True

        if not skip_file:
            data.append((base_name, ext, program))
         #print(f'{f_name}: {file_info["file_date"]}일, 열린 프로그램: {file_info["program"]}')
        print(f'{os.path.splitext(f_name)[0]}{os.path.splitext(f_name)[1]}: {file_info["file_date"]}일, 열린 프로그램: {os.path.basename(file_info["program"])}')
       
    
    #csv 파일 저장할 폴더 생성 
    #folder_path = 'C:\\Users\\User\\Project404'
    #if not os.path.exists(folder_path):
        #os.mkdir(folder_path)
    #data 리스트를 DataFrame으로 변환
    #df = pd.DataFrame(data, columns=['name', 'ext', 'program'])
    #CSV 파일로 저장
    #file_path = os.path.join('C:\\Users\\User\\Project404', 'data.csv')
    #df.to_csv(file_path, index=False,encoding='CP949')
            
if __name__ == "__main__":
    SortTwoWeeks()
# Out:
# 기타.lnk: 2023-08-19일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 너구리.jpg.lnk: 2023-08-19일, 열린 프로그램: .jpg 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# CustomDestinations: 2023-08-19일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 다운로드.lnk: 2023-08-19일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# IEEE 논문.pdf.lnk: 2023-08-19일, 열린 프로그램: Hpdf.exe" "%1"
# 1570944769 paper.pdf.lnk: 2023-08-19일, 열린 프로그램: Hpdf.exe" "%1"
# 이브와 자동화.docx.lnk: 2023-08-19일, 열린 프로그램: Hword.exe" "%1"
# Project404.lnk: 2023-08-19일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# data.csv.lnk: 2023-08-19일, 열린 프로그램: hcell.exe" "%1"
# 인터넷.lnk: 2023-08-19일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (88).lnk: 2023-08-19일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay---.lnk: 2023-08-19일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=11824&WindowId=329738.lnk: 2023-08-19일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ch03.lnk: 2023-08-18일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# mnist_show.py.lnk: 2023-08-18일, 열린 프로그램: py.exe" "%L" %*
# neuralnet_mnist_batch.py.lnk: 2023-08-18일, 열린 프로그램: py.exe" "%L" %*
# 카카오톡 받은 파일.lnk: 2023-08-18일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 이브와.pptx.lnk: 2023-08-18일, 열린 프로그램: hshow.exe" "%1"
# EVA.lnk: 2023-08-18일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# test.py.lnk: 2023-08-18일, 열린 프로그램: py.exe" "%L" %*
# Project_.lnk: 2023-08-18일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-gamingoverlay--kglcheck- (2).lnk: 2023-08-18일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# System_6주차.pdf.lnk: 2023-08-16일, 열린 프로그램: Hpdf.exe" "%1"
# music.zip.lnk: 2023-08-16일, 열린 프로그램: idlist,%I,%L
# ms-actioncentercontrolcenter-inputswitcher&suppressAnimations=false&showFooter=false&allowPageNavigation=false (4).lnk: 2023-08-16일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# upx.lnk: 2023-08-16일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# output.asm.lnk: 2023-08-16일, 열린 프로그램: .asm 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# socket_connect.lnk: 2023-08-16일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Server.java.lnk: 2023-08-16일, 열린 프로그램: idea64.exe" "%1"
# 아부지 쇼핑몰 (8).lnk: 2023-08-15일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 아부지 회사 홈페이지.txt.lnk: 2023-08-15일, 열린 프로그램: .txt 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# moblie Project (2).lnk: 2023-08-15일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# PeepProject.zip.lnk: 2023-08-15일, 열린 프로그램: idlist,%I,%L
# socket.pptx.lnk: 2023-08-15일, 열린 프로그램: hshow.exe" "%1"
# Win7.lnk: 2023-08-15일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Windows 7 x64.vmx.lnk: 2023-08-15일, 열린 프로그램: vmware.exe" -t "%1"
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (87).lnk: 2023-08-15일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 최종-피드백정리-SW개발_HW제작설계서_응용소프트웨어(개인정보 기재x) (1).pptx.lnk: 2023-08-15일, 열린 프로그램: hshow.exe" "%1"
# 최종본_프로보노 ICT멘토링 개발보고서.hwp.lnk: 2023-08-15일, 열린 프로그램: Hwp.exe" "%1"
# 최종-피드백정리-SW개발_HW제작설계서_응용소프트웨어(개인정보 기재x).pptx.lnk: 2023-08-15일, 열린 프로그램: hshow.exe" "%1"
# 별아띠 중간점검 설계도.pptx.lnk: 2023-08-15일, 열린 프로그램: hshow.exe" "%1"
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=14292&WindowId=526652.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=16000&WindowId=526326.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=13376&WindowId=395380.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=16412&WindowId=330026.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=18576&WindowId=985274.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=8796&WindowId=197578.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=16720&WindowId=197454.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (86).lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# sample.lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# sample.sln.lnk: 2023-08-14일, 열린 프로그램: VSLauncher.exe" "%1"
# 로컬 디스크 (C).lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Win7Virtual.lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Share.lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# http--www.msftconnecttest.com-redirect.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (85).lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-inputswitcher&suppressAnimations=false&showFooter=true&allowPageNavigation=false.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (84).lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# Win7_Ult_K_SP1_Korean_COEM_x64.iso.lnk: 2023-08-14일, 열린 프로그램: .iso 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# AutomaticDestinations: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 내 PC.lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 로컬 디스크 (C) (2).lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# sym.lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# websym.lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (83).lnk: 2023-08-14일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 23_PF029 (2).lnk: 2023-08-14일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# T.apk.lnk: 2023-08-14일, 열린 프로그램: .apk 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# test.apk.lnk: 2023-08-14일, 열린 프로그램: .apk 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Constellation2.zip.lnk: 2023-08-13일, 열린 프로그램: idlist,%I,%L
# Constellation.zip.lnk: 2023-08-13일, 열린 프로그램: idlist,%I,%L
# ms-actioncentercontrolcenter-inputswitcher&suppressAnimations=false&showFooter=false&allowPageNavigation=false (3).lnk: 2023-08-13일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# StarGuide.lnk: 2023-08-13일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# StarGuide.sln.lnk: 2023-08-13일, 열린 프로그램: VSLauncher.exe" "%1"
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (82).lnk: 2023-08-13일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 23_PF029.sln.lnk: 2023-08-13일, 열린 프로그램: VSLauncher.exe" "%1"
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=18228&WindowId=3409348.lnk: 2023-08-13일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=25716&WindowId=3278276.lnk: 2023-08-13일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=12264&WindowId=4066266.lnk: 2023-08-13일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=13652&WindowId=1640228.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=26100&WindowId=1377526.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=9248&WindowId=1246454.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=20788&WindowId=1115382.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=23568&WindowId=3084136.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=14528&WindowId=657782.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=612&WindowId=526710.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=19876&WindowId=3477422.lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# image.lnk: 2023-08-12일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# robo_head.png.lnk: 2023-08-12일, 열린 프로그램: .png 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (81).lnk: 2023-08-12일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 게럽.mp3.lnk: 2023-08-11일, 열린 프로그램: .mp3 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# intel(r)_usb_3.0_extensible_host_controller_driver_5.0.4.43_v2.zip.lnk: 2023-08-11일, 열린 프로그램: idlist,%I,%L
# Guest (3).lnk: 2023-08-11일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-settings-bluetooth.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (80).lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=14544&WindowId=4131002.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=8936&WindowId=788546.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=15912&WindowId=591876.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=4792&WindowId=329982.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=17556&WindowId=1180926.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=8740&WindowId=460936.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=12104&WindowId=1181866.lnk: 2023-08-11일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=16852&WindowId=6686540.lnk: 2023-08-10일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=8188&WindowId=262854.lnk: 2023-08-10일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=10232&WindowId=394814.lnk: 2023-08-10일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=11028&WindowId=5703524.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=12648&WindowId=788400.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=3792&WindowId=722814.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=15804&WindowId=657316.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=376&WindowId=526244.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=10448&WindowId=591718.lnk: 2023-08-09일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=7932&WindowId=591810.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=8420&WindowId=1311786.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=3848&WindowId=1180714.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=1856&WindowId=327790.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=5392&WindowId=196844.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=15248&WindowId=67110.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=33520&WindowId=2884966.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=35820&WindowId=2688358.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=13388&WindowId=1971220.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=22784&WindowId=14224278.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-gamingoverlay--startuptips-TitleId=1811699532&ProcessId=17320&WindowId=2561156.lnk: 2023-08-08일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# 23_PF029.lnk: 2023-08-08일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Project (7).lnk: 2023-08-08일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# robots.txt.lnk: 2023-08-08일, 열린 프로그램: .txt 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 스크린샷 (2).lnk: 2023-08-07일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# 스크린샷 2023-08-07 174331.png.lnk: 2023-08-07일, 열린 프로그램: .png 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-screensketchedit&source=Toast&sharedAccessToken=B56BFECB-585A-411D-9754-15BDA660B2DA&secondarySharedAccessToken=336FE681-923A-4061-A036-12295EE18D99&isTemporary=false&saved=true.lnk: 2023-08-07일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (79).lnk: 2023-08-07일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# CH 6 학습 관련 기술들 (1).pptx.lnk: 2023-08-07일, 열린 프로그램: hshow.exe" "%1"
# CH 6 학습 관련 기술들.zip.lnk: 2023-08-07일, 열린 프로그램: idlist,%I,%L
# '[밑바닥부터 시작하는 딥러닝] 4장 신경망 학습' 수정하기.html.lnk: 2023-08-07일, 열린 프로그램: iexplore.exe" %1
# MainProject.lnk: 2023-08-07일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# MainProject.sln.lnk: 2023-08-07일, 열린 프로그램: VSLauncher.exe" "%1"
# jingles-for-fairytales-pt-1-14-154394.mp3.lnk: 2023-08-07일, 열린 프로그램: .mp3 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# tvari-tokyo-cafe-159065.mp3.lnk: 2023-08-07일, 열린 프로그램: .mp3 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# tvari-tokyo-cafe-159065.mp3.crdownload.lnk: 2023-08-07일, 열린 프로그램: .crdownload 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Black-white-piano-ambient-221494.zip.lnk: 2023-08-07일, 열린 프로그램: idlist,%I,%L
# Broken-heart-75143.zip.lnk: 2023-08-07일, 열린 프로그램: idlist,%I,%L
# Cinematic-suspenseful-piano-131861.zip.lnk: 2023-08-07일, 열린 프로그램: idlist,%I,%L
# music.lnk: 2023-08-07일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# wbs.xlsx.lnk: 2023-08-07일, 열린 프로그램: hcell.exe" "%1"
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (78).lnk: 2023-08-07일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
# t1.unitypackage.lnk: 2023-08-07일, 열린 프로그램: .unitypackage 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# StarGuide-EyeTrackingEX.lnk: 2023-08-06일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# EyeTrackingEX.unitypackage.lnk: 2023-08-06일, 열린 프로그램: .unitypackage 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# git.lnk: 2023-08-06일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# CombineProject.lnk: 2023-08-06일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Combine.apk.lnk: 2023-08-06일, 열린 프로그램: .apk 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# Script.lnk: 2023-08-06일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# GameClear.cs.lnk: 2023-08-06일, 열린 프로그램: .cs 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# .editorconfig.lnk: 2023-08-06일, 열린 프로그램:  파일에 대한 기본 프로그램을 찾을 수 없습니다.
# GameOver.cs.lnk: 2023-08-06일, 열린 프로그램: .cs 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# KakaoTalk_20230806_120712841.jpg.lnk: 2023-08-06일, 열린 프로그램: .jpg 파일에 대한 기본 프로그램을 찾을 수 없습니다.
# ms-actioncentercontrolcenter-&suppressAnimations=false&showFooter=true&allowPageNavigation=true (77).lnk: 2023-08-06일, 열린 프로그램: 바로가기 대상 파일을 찾을 수 없습니다.
